# %% [markdown]
# # 데이터 과학 프로젝트
#
# 저장은 신경 쓰지 않아도 됩니다. **10분마다 자동으로 선생님께 저장**됩니다.
#
# 아래 폰트 셀만 한 번 실행하고 바로 시작하세요.

# %% [markdown]
# ## 한글 폰트 설정 (탭을 새로 열 때마다 한 번)
#
# 실행하지 않으면 그래프의 한글이 네모(□□□)로 깨집니다.

# %%
from pyodide.http import pyfetch
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

FONT_URL = "https://cdn.jsdelivr.net/gh/google/fonts@main/ofl/nanumgothic/NanumGothic-Regular.ttf"

res = await pyfetch(FONT_URL)
with open("NanumGothic.ttf", "wb") as f:
    f.write(await res.bytes())

fm.fontManager.addfont("NanumGothic.ttf")
plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams["axes.unicode_minus"] = False

print("한글 폰트 준비 완료")

# %% [markdown]
# ## 여기서부터 내 작업
#
# 활동 기록지 1단계에 적은 **탐구 질문**을 아래에 옮겨 적고 시작하세요.
# 셀마다 *무엇을 하는지*가 아니라 **왜 이렇게 했는지**를 주석으로 남깁니다.

# %%
# 탐구 질문:

# %%
import pandas as pd

df = pd.read_csv("내파일.csv")   # ← 파일 이름을 바꾸세요
                                 # 한글이 깨지면 encoding="cp949" 를 넣어 보세요
print(df.shape)
df.head()

# %%
# 여기부터 직접 작성
